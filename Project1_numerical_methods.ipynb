# %% [markdown]
# <a href="https://colab.research.google.com/github/johnryantaylor/QCES/blob/main/Project1_numerical_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1: Heat transport

# %% [markdown]
# In this project we will discretize and timestep two systems that describe heat transport. In the first part we will timestep a box model for the Earth's surface temperature with heat buffering provided by the deep ocean. In the second part, we will timestep the one-dimensional diffusion equation which can be used to describe heat moving through a medium (e.g. the ground or still air and water).
#
# Through this project, we will learn how to efficiently timestep ordinary and partial differential equations and examine errors introduced by the numerical discretization. We will also have the chance to explore the timescales and physical processes involved in heat transport in the climate system.

# %% [markdown]
# ## 1. Climate box model

# %% [markdown]
# In this part of the project we will timestep the following box model.
#
# $$ C_s \partial_t T = F(t) - \gamma(T-\theta) $$
#
# $$ C_d \partial_t \theta = \gamma (T-\theta) $$
#
# Here, $T(t)$ represents the global mean surface temperature as a function of time and $\theta(t)$ is the temperature of the deep ocean, both expressed as the difference between the temperature and a pre-industrial equilibrium in units of $^\circ K$. The net surface heat flux, $F(t)$, drives departures from the pre-industrial temperatures. The heat flux between the surface and deep ocean is assumed to be proportional to the difference between the surface and deep ocean temperatures. The constants are the heat capacity of the surface of the Earth, $C_s$, the heat capacity of the deep ocean, $C_d$, and the heat flux coefficient, $\gamma$, all given in units of $W/^\circ K/m^2$. Note that $C_s$ and $C_d$ (as defined in Nicklas et al. 2025) are heat capacities per year; i.e. $1/C_s$ tells us how much the surface temperature would increase if a flux of 1 $W/m^2$ were applied for one year.
#
# This model is inspired by a more complicated version of a two box climate model in the paper referenced below. (Interested students might consider adding some additional features from their model, but this is not required for this project).
#
# *Nicklas, J.M., Fox-Kemper, B. and Lawrence, C., 2025. Efficient Estimation of Climate State and Its Uncertainty Using Kalman Filtering with Application to Policy Thresholds and Volcanism. Journal of Climate, 38(5), pp.1235-1270.*
#
# Below, we start to build code to solve these equations. Execute the code cells below.  In some cases you will be asked to add code.
#
# Student tasks are in [Section 1.1](#section1pt1), [Section 1.2](#section1pt2), and [Section 1.3](#section1pt3).

# %%
# Before we start, import necessary libraries. Run this cell first.
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse as sp
import scipy.sparse.linalg as spla
import time

# %% [markdown]
# Now, let's define values for the various constants. These values are taken from Nicklas et al., 2025.

# %%
C_s = 17 # heat capacity of the Earth's surface (W/m^2/K)
C_d = 156 # heat capacity of the deep ocean (W/m^2/K)
gamma = 0.67 # heat exchange coefficient between surface and deep ocean (W/m^2/K)

print(1 / (gamma * (1/C_s + 1/C_d)))
# Out:
# 22.879820550427052

# %% [markdown]
# Now, let's define a function for F(t), the net surface heat flux (in units of $W/m^2$) that will force our model. This function is here to represent the heat imbalance caused by antropogenic greenhouse gases in the atmosphere. When $F=0$, there is no net surface heat flux. The argument, $t$, is the time in years. We will let $t=0$ denote the start of our additional warming, and we set $F=1$ if $t<200$ years and $F=0$ if $t>200$ years. This corresponds to a very bad-case emissions scenario with an abrupt drop in emissions after 200 years.

# %%
def F(t):
    return 1 if t < 200 else 0

# %% [markdown]
# Next, set the initial conditions. We will use arrays `T` and `theta`. `T[i]` represents the ith value in the array. We will use `T[0]` and `theta[0]` to hold the initial conditions. Subsequent values, `T[2]`, `T[3]`, etc. will be determined by timestepping the equations. We start by initializing the arrays using numpy and filling them with zeros and then set the initial values (this isn't necessary here since our values are zero anyway, but the code is here to that you can change the initial conditions easily)

# %%
Nt = 500 # number of time steps (including the starting point)
T = np.zeros(Nt) # surface temperature array
theta = np.zeros(Nt) # deep ocean temperature array
T[0] = 0 # initial surface temperature anomaly (ºK)
theta[0] = 0 # initial deep ocean temperature anomaly (ºK)

# %% [markdown]
# Now, create an array with the time (in years) corresponding to each time index. Also, calculate the timestep, `dt`.

# %%
t = np.linspace(0, 500, Nt) # time in years.  This starts at 0 and ends at 500, with Nt total points
dt = t[1] - t[0] # timestep in years

# %% [markdown]
# Finally, we are ready to create a for loop to timestep the equations listed at the top of the section.

# %% [markdown]
# ### 1.1 Student task:
# <a id='section1pt1'></a>
# Fill in the interior of the for loop to timestep the equations from the start of Section 1 using the Explicit Euler method.

# %%
mu_s = dt / C_s # put groupings of constants in variables to avoid having to perform the same divisions over and over
gamma_mu_d = gamma * dt / C_d
for i in range(0, Nt-1):
    T[i+1] = (1 - gamma * mu_s) * T[i] + gamma * mu_s * theta[i] + mu_s * F(t[i])
    theta[i+1] = (1 - gamma_mu_d) * theta[i] + gamma_mu_d * T[i]

# %% [markdown]
# After you are finished, run the cell below to plot the results

# %%
plt.plot(t,T,'r-')
plt.plot(t,theta,'b-')
plt.legend(['Surface temperature','Deep ocean temperature'])
plt.xlabel('Time (years)')
plt.ylabel('Temperature anomaly (ºK)')
plt.show()

# %% [markdown]
# ### 1.2 Student task
# <a id='section1pt2'></a>
# Discuss the rates of change the temperature of the Earth's surface and the deep ocean at the start of the model run.  Can you explain the response of $T$ and $\theta$ to the forcing by defining characteristic timescales from the box model equations?

# %% [markdown]
# INSERT DISCUSSION HERE (~1 paragraph)

# %% [markdown]
# ### 1.3 Student task
# <a id='section1pt3'></a>
# Modify the forcing function, `F(t)` above with 2-3 scenarios of your choice. Plot the temperature response for each scenario and briefly (2-3 sentences each) describe the temperature responses in each scenario. You will need to replicate some of the code blocks above so that you can produce a new set of plots below.

# %%
# piecewise linear form for F
def F(t):
    if t < 150:
      return t/75
    elif t < 300:
      return 4 - t/75
    else:
      return 0

# re-initialise (not actually necessary)
T[0] = 0
theta[0] = 0
for i in range(0, Nt-1):
    T[i+1] = (1 - gamma * mu_s) * T[i] + gamma * mu_s * theta[i] + mu_s * F(t[i])
    theta[i+1] = (1 - gamma_mu_d) * theta[i] + gamma_mu_d * T[i]

plt.plot(t,T,'r-')
plt.plot(t,theta,'b-')
plt.legend(['Surface temperature','Deep ocean temperature'])
plt.xlabel('Time (years)')
plt.ylabel('Temperature anomaly (ºK)')
plt.show()

# exponential increase (and then decrease) for F
def F(t):
    if t < 150:
      return np.exp(t/150) / (np.exp(1)-1)
    else:
      return np.exp((150-t)/150) / (np.exp(1)-1)

T[0] = 0
theta[0] = 0
for i in range(0, Nt-1):
    T[i+1] = (1 - gamma * mu_s) * T[i] + gamma * mu_s * theta[i] + mu_s * F(t[i])
    theta[i+1] = (1 - gamma_mu_d) * theta[i] + gamma_mu_d * T[i]

plt.plot(t,T,'r-')
plt.plot(t,theta,'b-')
plt.legend(['Surface temperature','Deep ocean temperature'])
plt.xlabel('Time (years)')
plt.ylabel('Temperature anomaly (ºK)')
plt.show()

# constant heating then constant cooling
def F(t):
    if t < 150:
      return 1
    else:
      return -1

T[0] = 0
theta[0] = 0
for i in range(0, Nt-1):
    T[i+1] = (1 - gamma * mu_s) * T[i] + gamma * mu_s * theta[i] + mu_s * F(t[i])
    theta[i+1] = (1 - gamma_mu_d) * theta[i] + gamma_mu_d * T[i]

plt.plot(t,T,'r-')
plt.plot(t,theta,'b-')
plt.legend(['Surface temperature','Deep ocean temperature'])
plt.xlabel('Time (years)')
plt.ylabel('Temperature anomaly (ºK)')
plt.show()

# %% [markdown]
# INSERT DISCUSSION HERE

# %% [markdown]
# ## 2. Diffusion equation

# %% [markdown]
# In this part of the project we will solve the 1-D diffusion equation:
#
# $$ \partial_t c = \kappa \partial_x^2 c $$
#
# We will use second order finite differences to approximate the $x$-derivatives, and we will implement and compare two timestepping methods.
#
# Student tasks are in [Section 2.1](#section2pt1), [Section 2.2](#section2pt2), and [Section 2.3](#section2pt3).

# %% [markdown]
# First, let's discretize the second order derivative using finite differences. The function below builds a coefficient matrix, $M$, so that $Mc$ is a discretized version of $\partial^2_x c$, where in our discretized version $c$ is a column vector.

# %%
def construct_M(x):
# Build a coefficient matrix, such that M*c is the discrete version of d^2/dx^2(c)
    dx = x[1] - x[0]  # Infer the uniform grid spacing
    M = (np.diag(np.ones(Nx-1), -1) - 2*np.diag(np.ones(Nx), 0) + np.diag(np.ones(Nx-1), 1)) / dx**2
    M = sp.csr_matrix(M) # Turn M into a sparse matrix to save memory and improve speed
    return M

# %% [markdown]
# Now, define two functions to timestep the diffusion equation. The code below timesteps the diffusion equation using the expicit Euler method. The function takes in a vector of discrete positions, `x`, discrete times, `t`, and the diffusivity, `kappa`. The vectors `x` and `t` dictate the discretization of the problem in space and time, and the grid spacing must be constant in space and time. The boundary conditions are $\partial_x c=0$ at the starting and ending points in `x`.

# %%
def EE(x, t, kappa):
# This function timesteps the diffusion equation with homogeneous Neumann boundary conditions
# using the explicit Euler and second order finite difference methods

    start_time = time.time()  # Start a timer

    # Infer the timestep from the time array
    dt = t[1] - t[0]

    M = construct_M(x)  # Construct the coefficient matrix for the second derivative

    # Set the number of gridpoints in x and t
    Nx = len(x); Nt = len(t)

    # Create an empty sparse array to store the solution
    c = np.zeros((Nx, Nt))

    c[:, 0] = set_ics(x, kappa, 10)  # Set the initial condition

    for k in range(1, Nt):  # loop over the number of timesteps
      c[:,k] = c[:,k-1] + dt * kappa * M @ c[:,k-1]
      # Enforce the boundary conditions (no flux)
      c[0, k] = c[1, k]
      c[-1, k] = c[-2, k]

    end_time = time.time()  # Print the elapsed time

    print(f"Explicit Euler method took {end_time - start_time:.2f} seconds")

    return c

# %% [markdown]
# Similarly, the function below timesteps the diffusion equation with the Crank-Nicolson method

# %%
def CN(x, t, kappa):
# This function timesteps the diffusion equation with homogeneous Neumann boundary conditions
# using the explicit Euler and second order finite difference methods
    start_time = time.time()  # Start a timer

    # Infer the timestep from the time array
    dt = t[1] - t[0]

    M = construct_M(x)  # Construct the coefficient matrix for the second derivative

    # Set the number of gridpoints in x and t
    Nx = len(x); Nt = len(t)

    A = sp.eye(Nx) - 0.5 * dt * kappa * M  # This matrix appears on the LHS in the C-N scheme
    A_inv = spla.inv(A) # Calculate the inverse of A (this only needs to be done once)

    # Create an empty sparse array to store the solution
    c = np.zeros((Nx, Nt))

    c[:, 0] = set_ics(x, kappa, 10)  # Set the initial condition

    for k in range(1, Nt): # loop over the number of timesteps
        c[:, k] = A_inv @ (c[:, k-1] + 0.5 * dt * kappa * (M @ c[:, k-1]))
        # Enforce the boundary conditions
        c[0, k] = c[1, k]
        c[-1, k] = c[-2, k]

    end_time = time.time()  # Print the elapsed time

    print(f"Crank-Nicolson method took {end_time - start_time:.2f} seconds")

    return c

# %% [markdown]
# Next, create a function to set the initial conditions. The exact solution to the unbounded diffusion equation with a delta function initial condition is:
#
# $$\left(\frac{1}{4\pi\kappa t}\right)^{1/2}e^{-x^2/(4\kappa t)}$$
#
# The function below sets the initial condition by evaluating the exact solution at a given time. Note that it is important that we don't evaluate the exact solution at `t_ic=0` since this will return a delta function which will be undefined on our finite grid. The value of `t_ic` is set within the `EE` and `CN` functions.

# %%
# Function to set the initial condition from the exact solution at time t_start
def set_ics(x, kappa, t_ic):
    c_ic = (4*np.pi*kappa*t_ic)**(-0.5)*np.exp(-x**2 / (4*kappa*t_ic))
    # Enforce the boundary conditions
    c_ic[0] = c_ic[1]
    c_ic[-1] = c_ic[-2]
    return c_ic

# %% [markdown]
# Finally, define some parameters and the x and t vectors:

# %%
# Defining parameters
kappa = 0.001  # diffusivity
# original value 0.001
# Timestepping parameters
t_start = 0  # start time (note that this is not the same time used to evaluate the exact solution to set the ICs)
t_end = 10  # end time
Nt = 1000  # number of timesteps

# Size of the physical domain
x_start = -1
x_end = 1
Nx = 100

t = np.linspace(t_start, t_end, Nt)  # Create a vector of times
x = np.linspace(x_start, x_end, Nx)  # Create a vector for x

# %% [markdown]
# Run each method once:

# %%
# Run the simulations
c_EE = EE(x, t, kappa) # explicit Euler
c_CN = CN(x, t, kappa) # Crank-Nicolson
# Out:
# Explicit Euler method took 0.06 seconds
# Crank-Nicolson method took 0.07 seconds
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:606: SparseEfficiencyWarning: splu converted its input to CSC format
#   return splu(A).solve
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/linalg/_matfuncs.py:76: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   Ainv = spsolve(A, I)

# %% [markdown]
# and finally, plot the results side-by-side

# %%
# Plot the results
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.pcolormesh(x, t, c_EE.T, shading='auto')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Explicit Euler')

plt.subplot(1, 2, 2)
plt.pcolormesh(x, t, c_CN.T, shading='auto')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Crank-Nicolson')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Student investigation

# %% [markdown]
# ### 2.1 Stability
# <a id='section2pt1'></a>
# The explicit Euler and Crank-Nicolson methods have different stability properties. To explore this, try increasing the diffusivity, $\kappa$, and see how each method responds. Discuss your findings below (~2-3 sentences).

# %% [markdown]
# Fourier stability analysis shows that the explicit Euler method, when applied to the diffusion, is stable so long as $\kappa$ is not too big, whereas the Crank-Nicolson method is stable for all $\kappa$. Indeed, for our values of $\Delta x$ and $\Delta t$, we see that increasing $\kappa$ above about 0.025 causes a breakdown of the explicit Euler scheme as implemented here, while the Crank-Nicolson scheme is well-behaved for $\kappa$ as big as $10$.

# %% [markdown]
# ### 2.2 Accuracy
# <a id='section2pt2'></a>
# Next, we will examine the accuracy of the numerical methods used above. In order to do this, it is useful to compare our numerical solutions with the exact solution to the diffusion equation. Below, write code to plot the exact solution and the numerical solution using explicit Euler and Crank-Nicolson at the final time ($t=10$). Note that you can use the exact solution to the diffusion equation in an unbounded domain in $x$ and keep in mind that the exact solution and numerical solutions will differ for later times when boundary effects are felt.

# %%
exact_end = (4*np.pi*kappa*(10+t_end))**(-0.5)*np.exp(-x**2 / (4*kappa*(10+t_end)))
plt.plot(x,exact_end,'black')
plt.plot(x,c_EE[:,-1],'r--')
plt.plot(x,c_CN[:,-1],'b:')
plt.legend(['Exact solution','Explicit Euler','Crank-Nicolson'])
plt.xlabel('$x$')
plt.ylabel('Concentration $c$')
plt.title('Comparison of the numerical solutions\n with the exact unbounded solution at time $t=10$.')
plt.show()

plt.plot(x,exact_end,'black')
plt.plot(x,c_EE[:,-1],'r')
plt.plot(x,c_CN[:,-1],'b')
plt.legend(['Exact solution','Explicit Euler','Crank-Nicolson'])
plt.xlabel('$x$')
plt.ylabel('Concentration $c$')
plt.xlim((-0.025,0.025))
plt.ylim((1.975,1.995))
plt.title('Zoomed-in comparison of the numerical solutions\n with the exact unbounded solution at time $t=10$.')
plt.show()

# %% [markdown]
# The difference between the exact solution and the numerical approximation can be quantified by various measures of error. The *local error* is the difference between the exact solution and the numerical approximation after one timestep. The *global error* is the difference between the solutions after a fixed amount of time (which includes the accumulation of multiple steps of local error). A method is first order accurate if the global error is linearly proportional to the timestep. A method is second order accurate if the global error varies quadratically with the timestep. Below, calculate and plot the global error for the Explicit Euler and Crank-Nicolson methods and use your results to infer the order of accuracy of each scheme.

# %% [markdown]
# PLOT GLOBAL ERROR FOR EACH SCHEME (1-2 figures) AND DISCUSS ORDER OF ACCURACY (2-3 sentences)

# %%
new_kappa = 0.01
exact_end = (4*np.pi*new_kappa*(10+t_end))**(-0.5)*np.exp(-x**2 / (4*new_kappa*(10+t_end)))
dt = [0.0001,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01]
global_error_EE = np.zeros(len(dt))
global_error_CN = np.zeros(len(dt))
for i in range(len(dt)):
  Nt = int(10/dt[i] + 1)
  t = np.linspace(t_start, t_end, Nt)

  c_EE = EE(x,t,new_kappa)
  c_CN = CN(x,t,new_kappa)
  global_error_EE[i] = np.linalg.norm(c_EE[:,-1] - exact_end)
  global_error_CN[i] = np.linalg.norm(c_CN[:,-1] - exact_end)

plt.plot(dt,global_error_EE,'o-')
plt.xlabel('Timestep $\Delta t$')
plt.ylabel('Global error')
plt.title('Relationship between timestep and global error\n at time $t=10$ in the explicit Euler scheme.')
plt.show()
plt.plot(dt,global_error_CN,'o-')
plt.xlabel('Timestep $\Delta t$')
plt.ylabel('Global error')
plt.title('Relationship between timestep and global\n error at time $t=10$ in the Crank-Nicolson scheme.')
plt.show()
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:16: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipython-input-2094668395.py:16: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel('Timestep $\Delta t$')
# /tmp/ipython-input-2094668395.py:21: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel('Timestep $\Delta t$')
# Explicit Euler method took 5.88 seconds
# Crank-Nicolson method took 4.26 seconds
# Explicit Euler method took 0.56 seconds
# Crank-Nicolson method took 0.34 seconds
# Explicit Euler method took 0.28 seconds
# Crank-Nicolson method took 0.18 seconds
# Explicit Euler method took 0.17 seconds
# Crank-Nicolson method took 0.14 seconds
# Explicit Euler method took 0.12 seconds
# Crank-Nicolson method took 0.10 seconds
# Explicit Euler method took 0.10 seconds
# Crank-Nicolson method took 0.09 seconds
# Explicit Euler method took 0.13 seconds
# Crank-Nicolson method took 0.08 seconds
# Explicit Euler method took 0.07 seconds
# Crank-Nicolson method took 0.07 seconds
# Explicit Euler method took 0.06 seconds
# Crank-Nicolson method took 0.08 seconds
# Explicit Euler method took 0.06 seconds
# Crank-Nicolson method took 0.06 seconds
# Explicit Euler method took 0.05 seconds
# Crank-Nicolson method took 0.06 seconds

# %% [markdown]
# The theory predicts that the explicit Euler method is first order accurate in time, while the Crank-Nicolson method is second order. Happily, when we plot the global error at time $t=10$ for various choices of timestep $\Delta t$ we observe that the global error varies linearly and quadratically with timestep for the explicit Euler and Crank-Nicolson methods respectively, in agreement with the theory.

# %% [markdown]
# Finally, select a given error tolerance and explore whether explicit Euler or Crank-Nicoslon is more efficient (faster) at generating solutions with error less than your error tolerance. Discuss your conclusion and add supporting figures if necessary.

# %% [markdown]
# INSERT DISCUSSION OF ERROR HERE (~1 paragraph).  OPTIONALLY ADD PLOTS BY INSERTING A CODE BLOCK BELOW.

# %%
kappa = 0.001
tau = 0.1 # error tolerance

global_error = 10
dt = 0.02
while global_error > tau:
  dt = 0.5 * dt
  Nt = 10/dt + 1
  c_EE = EE(x, t, kappa)
  global_error = np.linalg.norm(c_EE[:,-1] - exact_end)
  print(global_error)
# Out:
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.00 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.00 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.00 seconds
# 2.707191488424645
# Explicit Euler method took 0.00 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# Explicit Euler method took 0.01 seconds
# 2.707191488424645
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2265466449.py in <cell line: 0>()
#       7   dt = 0.5 * dt
#       8   Nt = 10/dt + 1
# ----> 9   c_EE = EE(x, t, kappa)
#      10   global_error = np.linalg.norm(c_EE[:,-1] - exact_end)
#      11   print(global_error)
#
# /tmp/ipython-input-3552262878.py in EE(x, t, kappa)
#      19
#      20     for k in range(1, Nt):  # loop over the number of timesteps
# ---> 21       c[:,k] = c[:,k-1] + dt * kappa * M @ c[:,k-1]
#      22       # Enforce the boundary conditions (no flux)
#      23       c[0, k] = c[1, k]
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_matrix.py in __rmul__(self, other)
#      46
#      47     def __rmul__(self, other):
# ---> 48         return self._rmatmul_dispatch(other)
#      49
#      50     # Restore matrix power
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_base.py in _rmatmul_dispatch(self, other)
#     886     def _rmatmul_dispatch(self, other):
#     887         if isscalarlike(other):
# --> 888             return self._mul_scalar(other)
#     889         else:
#     890             # Don't use asarray unless we have to
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_data.py in _mul_scalar(self, other)
#     133
#     134     def _mul_scalar(self, other):
# --> 135         return self._with_data(self.data * other)
#     136
#     137
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_compressed.py in _with_data(self, data, copy)
#    1170         """
#    1171         if copy:
# -> 1172             return self.__class__((data, self.indices.copy(),
#    1173                                    self.indptr.copy()),
#    1174                                   shape=self.shape,
#
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/_compressed.py in __init__(self, arg1, shape, dtype, copy, maxprint)
#     112         if dtype is not None:
#     113             newdtype = getdtype(dtype)
# --> 114             self.data = self.data.astype(newdtype, copy=False)
#     115
#     116         self.check_format(full_check=False)
#
# KeyboardInterrupt:

# %%
kappa = 0.001

# choose tolerance for global error at t=10
tau = 0.1

# seek timestep by computing local error for the first step
# then assume local error accumulates s.t. global error will be O(Nt^2 * local error)
dt = 0.2
Nt = 10/dt + 1
local_error = 2 * tau
while local_error > (tau / (Nt ** 2)) :
  dt = 0.9 * dt
  print("dt=",dt)
  Nt = 10/dt+1
  print("Nt=",Nt)
  c_EE = EE(x, [0, dt], kappa)
  exact = (4*np.pi*kappa*(10+dt))**(-0.5)*np.exp(-x**2 / (4*kappa*(10+dt))) # remember the IC was really evaluated at t=10
  local_error = np.linalg.norm(c_EE[:,1]-exact)
  print("local_error=",local_error)

t=np.linspace(t_start, t_end, int(Nt))
c_EE = EE(x, t, kappa)
global_error = np.linalg.norm(c_EE[:,-1] - exact_end)
print("global_error=",global_error)

# %% [markdown]
# ### 2.3 Boundary conditions for Crank-Nicolson scheme
# <a id='section2pt3'></a>
#
# The application of the boundary conditions for the Crank-Nicolson method isn't quite right in the script above (but the boundary conditions aren't very important in this example). Account for the boundary conditions by modifying the coefficient matrix. This should ensure that the boundary conditions are applied to the implicit and explicit terms involved in the Crank-Nicolson update. Plot your results below and verify that the boundary conditions are satisfied.  How would you handle fixed value (Dirichlet) and fixed gradient (Neumann) boundary conditions?

# %%
def modified_CN(x, t, kappa):
# This function timesteps the diffusion equation with homogeneous Neumann boundary conditions
# using the explicit Euler and second order finite difference methods
    start_time = time.time()  # Start a timer

    # Infer the timestep from the time array
    dt = t[1] - t[0]

    M = construct_M(x)  # Construct the coefficient matrix for the second derivative
    dx = x[1]-x[0]
    M[0,1] = 2 / (dx**2) # used the fact that centred differences are zero at x[0]
    M[-1,-2] = 2 / (dx**2)

    # Set the number of gridpoints in x and t
    Nx = len(x); Nt = len(t)

    A = sp.eye(Nx) - 0.5 * dt * kappa * M  # This matrix appears on the LHS in the C-N scheme
    A_inv = spla.inv(A) # Calculate the inverse of A (this only needs to be done once)

    # Create an empty sparse array to store the solution
    c = np.zeros((Nx, Nt))

    c[:, 0] = set_ics(x, kappa, 10)  # Set the initial condition

    for k in range(1, Nt): # loop over the number of timesteps
        c[:, k] = A_inv @ (c[:, k-1] + 0.5 * dt * kappa * (M @ c[:, k-1]))
        # Enforce the boundary conditions
        #c[0, k] = c[1, k]
        #c[-1, k] = c[-2, k]

    end_time = time.time()  # Print the elapsed time

    print(f"Crank-Nicolson method took {end_time - start_time:.2f} seconds")

    return c

kappa = 0.001
Nt = 1000
t = np.linspace(t_start, t_end, Nt)
x = np.linspace(x_start, x_end, Nx)

c_original = CN(x,t,kappa)
c_modified = modified_CN(x,t,kappa)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.pcolormesh(x, t, c_original.T, shading='auto')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Original implimentation')

plt.subplot(1, 2, 2)
plt.pcolormesh(x, t, c_modified.T, shading='auto')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Proper handling of boundary conditions')

plt.tight_layout()
plt.show()

print("c(x_start,t=10) =",c_modified[0,-1])
print("c(x_start+dx,t=10) =",c_modified[1,-1])
print("c(x_end-dx,t=10) =",c_modified[-2,-1])
print("c(x_end,t=10) =",c_modified[-1,-1])
# Out:
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:606: SparseEfficiencyWarning: splu converted its input to CSC format
#   return splu(A).solve
# /usr/local/lib/python3.12/dist-packages/scipy/sparse/linalg/_matfuncs.py:76: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   Ainv = spsolve(A, I)
# Crank-Nicolson method took 0.06 seconds
# Crank-Nicolson method took 0.05 seconds
# c(x_start,t=10) = 1.6410599980700807e-05
# c(x_start+dx,t=10) = 1.8382249812690924e-05
# c(x_end-dx,t=10) = 1.83822498126906e-05
# c(x_end,t=10) = 1.6410599980700576e-05

# %% [markdown]
# Above we see that the first two and last two values of c at time $t=10$ are in very good agreement, particularly considering the rounding errors that would accumulate over 1000 timesteps.

# %% [markdown]
# ADD DISCUSSION OF DIRICHLET AND NEUMANN BOUNDARY CONDITIONS HERE (NO CODE NEEDED)
